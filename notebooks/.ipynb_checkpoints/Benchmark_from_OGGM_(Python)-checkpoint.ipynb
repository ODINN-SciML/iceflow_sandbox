# %% [markdown]
# This notebook aims to benchmark the new Julia iceflow model SIA1D implemented in OGGM
#
# For this notebook to work, downloading the OGGM version available at : https://github.com/lucillegimenes/oggm is necessary.

# %%
# %%
import time
import timeit

import oggm
from oggm import cfg, utils, workflow, tasks, graphics, global_tasks
from oggm.core import flowline, massbalance
import salem
import xarray as xr
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import functools
from oggm.shop import gcm_climate

cfg.initialize(logging_level='WARNING')

cfg.PARAMS['use_multiprocessing']=True
cfg.PATHS['working_dir'] = '/home/gimenelu/Run_oggm_bench/'
cfg.PARAMS['continue_on_error'] = True

cfg.PARAMS['use_inversion_params_for_run']= True
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.1/elev_bands/W5E5_spinup/'
# Out:
# 2023-09-08 13:26:28: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2023-09-08 13:26:28: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2023-09-08 13:26:28: oggm.cfg: Multiprocessing: using all available processors (N=16)
# 2023-09-08 13:26:28: oggm.cfg: Multiprocessing switched ON after user settings.
# 2023-09-08 13:26:28: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.

# %%
from juliacall import Main as jl
jl.seval("using Revise")
jl.seval("using Distributed")
jl.seval("using ProgressMeter")
jl.seval("using OrdinaryDiffEq")
jl.seval("using Random")
jl.seval("using SugarBLAS")
jl.seval("using Statistics")
jl.seval("using BenchmarkTools")
jl.seval("using JLD2")
jl.seval("using DataFrames")
jl.seval("using Plots")
jl.seval("using StatsPlots")
jl.seval("using Logging: global_logger")
jl.seval("using TerminalLoggers: TerminalLogger")
jl.seval("using CategoricalArrays")

# %% [markdown]
# ## Benchmarking Julia solvers for SIA1D

# %%
#List of Julia solvers to test
ude_solvers = [jl.BS3(),jl.OwrenZen3(),jl.RDPK3Sp35(),jl. ROCK4(), 
               jl.Ralston(),jl.VCABM5(),jl.Vern6()]


#list of glaciers to test the Julia solvers on 
rgi_ids=["RGI60-11.03638","RGI60-11.03671","RGI60-11.03643","RGI60-11.03674","RGI60-11.03756", #Argentière, Gébroulaz, Mer de Glace,St-Sorlin, Sarennes
    "RGI60-16.00543","RGI60-16.01339", #Zongo, Antizana
    "RGI60-11.03232", #Ossoue
    "RGI60-11.03646", #Bossons
    "RGI60-15.03591", #Mera
    "RGI60-15.03733", #Khumbu
    "RGI60-14.07524", #Siachen
    "RGI60-13.54431", #Fedtchenko
    "RGI60-01.05355"] #Alexander

gdirs= workflow.init_glacier_directories(rgi_ids, from_prepro_level=4,
                                         prepro_base_url=base_url, prepro_border=160)


samples = 6 #Numbers of runs for the task to get a good approximation of the running time
ny =300
    

#to benchmark all the glaciers from the list on different solvers
def BenchmarkingAll(rgi_list,solver_list,gdirs):

    reltol = 1e-5
    
    n = len(rgi_list)
    ude_benchmark = {"id":[], "ude_settings":[], "SemiImp_stats":[], "FluxBased_stats":[]}
    for r in rgi_list:
        #Initialize glacier
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        area.append(gdir.rgi_area_km2)
        
        ude_benchmark["id"].append(r)
        
        
        #Benchmarking OGGM schemes 
        cfg.PARAMS["evolution_model"] = "SemiImplicit"

        t_s_tmp=[]
        for t in range(0,samples): 
            tico = time.perf_counter()
            workflow.execute_entity_task(tasks.run_random_climate, gdir, y0 = 2003, nyears=ny,seed=1,store_fl_diagnostics=True,store_model_geometry=True)
            toco = time.perf_counter()
            t_s_tmp.append(toco-tico)

        t_stats_o = np.mean(t_s_tmp)
        ude_benchmark["SemiImp_stats"].append(t_stats_o)  


        cfg.PARAMS["evolution_model"] = "FluxBased"

        t_s_tmp=[]
        for t in range(0,samples):
            tico2 = time.perf_counter()
            workflow.execute_entity_task(tasks.run_random_climate, gdir, y0 = 2003, nyears=ny,seed=1,store_fl_diagnostics=True,store_model_geometry=True)
            toco2 = time.perf_counter()
            t_s_tmp.append(toco2-tico2)

        t_stats_o2 = np.mean(t_s_tmp)
        ude_benchmark["FluxBased_stats"].append(t_stats_o2)  
        
        cfg.PARAMS["evolution_model"] = "SIA1D"
        ude_settings={"solver":[],"time_stats":[]}
        
        for s in solver_list:

            cfg.PARAMS["Julia_solver"] = s

            ude_settings["solver"].append(s)
            t_stats=[]

            for t in range(0,samples):
                ticj = time.perf_counter()
                workflow.execute_entity_task(tasks.run_random_climate, gdir, y0 = 2003, nyears=ny,seed=1,store_fl_diagnostics=True,store_model_geometry=True)
                tocj = time.perf_counter()
                
                t_stats.append(tocj - ticj)

            ude_settings["time_stats"].append(t_stats)
        
        ude_benchmark["ude_settings"].append(ude_settings)

    return ude_benchmark
# Out:
# 2023-09-05 15:28:51: oggm.workflow: init_glacier_directories from prepro level 4 on 14 glaciers.
# 2023-09-05 15:28:51: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 14 glaciers
# 2023-09-05 15:28:51: oggm.workflow: WARNING: you are trying to run an entity task on 14 glaciers with multiprocessing turned off. OGGM will run faster with multiprocessing turned on.

# %%
cfg.PARAMS['use_multiprocessing'] = False #SIA1D doesn't work with mp turned on
result = BenchmarkingAll(rgi_ids,ude_solvers,gdirs)
# Out:
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:29:04: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:29:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:08: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:29:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:15: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:29:15: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:29:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:19: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:29:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:23: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:29:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:27: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:29:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:32: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:29:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:39: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:29:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:44: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:29:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:29:49: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:29:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:52: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:29:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:29:59: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:29:59: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:29:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:03: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:30:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:07: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:30:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:11: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:30:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:16: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:30:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:22: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:30:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:25: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:30:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:30:30: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:30:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:35: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:30:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:51: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:30:51: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:30:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:56: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:30:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:30:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:01: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:31:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:06: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:31:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:14: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:31:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:24: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:31:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:30: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:31:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:31:36: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:31:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:40: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:31:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:44: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:31:44: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:31:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:47: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:31:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:51: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:31:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:55: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:31:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:31:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:00: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:04: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:32:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:08: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:32:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:32:12: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:32:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:16: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:32:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:20: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:32:20: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:23: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:26: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:29: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:32:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:36: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:39: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:32:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:42: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:32:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:32:46: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:32:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:49: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:32:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:32:59: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:32:59: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:32:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:03: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:33:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:07: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:33:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:11: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:33:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:16: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:33:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:26: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:33:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:31: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:33:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:33:35: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:33:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:40: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:33:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:33:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:17: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:34:17: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:34:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:22: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:34:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:29: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:34:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:33: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:34:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:34:39: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# ...
# 2023-09-05 15:41:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:34: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:41:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:46: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:41:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:41:57: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:41:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:41:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:09: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:42:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:35: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:42:35: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:42:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:45: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:42:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:55: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:42:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:42:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:05: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:43:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:16: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:43:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:27: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:43:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:39: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:43:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# /home/gimenelu/oggm/oggm/utils/_workflow.py:2889: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return np.round(float(_area), decimals=3)
# 2023-09-05 15:43:52: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-05 15:43:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:55: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-05 15:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:43:59: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-05 15:43:59: oggm.cfg: PARAMS['Julia_solver'] changed from `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)` to `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:02: oggm.cfg: PARAMS['Julia_solver'] changed from `BS3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:44:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:05: oggm.cfg: PARAMS['Julia_solver'] changed from `OwrenZen3(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:08: oggm.cfg: PARAMS['Julia_solver'] changed from `RDPK3Sp35(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `ROCK4{Nothing}(0, 152, nothing)`.
# 2023-09-05 15:44:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:12: oggm.cfg: PARAMS['Julia_solver'] changed from `ROCK4{Nothing}(0, 152, nothing)` to `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))`.
# 2023-09-05 15:44:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:15: oggm.cfg: PARAMS['Julia_solver'] changed from `Ralston(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false))` to `VCABM5()`.
# 2023-09-05 15:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:19: oggm.cfg: PARAMS['Julia_solver'] changed from `VCABM5()` to `Vern6(stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true)`.
# 2023-09-05 15:44:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-05 15:44:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers

# %% [markdown]
# ### Plotting the benchmark results

# %%
#Plotting the results
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches


f= plt.subplots(figsize=(12, 8))
handles, labels = plt.gca().get_legend_handles_labels()  

ude_solvers_str=["BS3","OwrenZen3","RDPK3Sp35","ROCK4","Ralston","VCABM5","Vern6"]


ng=len(rgi_ids)
ns= len(ude_solvers_str)

mean_si = round(np.mean(test["SemiImp_stats"])*1e3)
std_si = round(np.std(test["SemiImp_stats"])*1e3)
mean_fb = round(np.mean(test["FluxBased_stats"])*1e3)
std_fb = round(np.std(test["FluxBased_stats"])*1e3)
mean_s =np.array([0]*ns)
std_s =np.array([0]*ns)



plt.xticks(rotation = 70)
plt.ylabel('time [ms]', fontsize = 14)
plt.xlabel('Glacier RGI ID')
colors=["maroon","orange","darkseagreen","cornflowerblue","mediumpurple","lightpink","forestgreen"]

point = Line2D([0], [0], label='Semi Implicit (mean = {} $\pm$ {} ms)'.format(mean_si, std_si), marker='+', markersize=10, 
         markeredgecolor='r', markerfacecolor='r', linestyle='')

point2 = Line2D([0], [0], label='Flux-based (mean = {} $\pm$ {} ms)'.format(mean_fb,std_fb), marker='+', markersize=10, 
         markeredgecolor='b', markerfacecolor='b', linestyle='')

for j in range(0,ns):
    mean_tmp=[]
    std_tmp=[]
    for i in range(0,ng):
    
        plt.plot(rgi_ids[i],np.mean(test["ude_settings"][i]["time_stats"][j])*1e3, marker='o', markersize=6,
             markeredgecolor='w',markerfacecolor=colors[j])
        
        mean_tmp.append(np.mean(test["ude_settings"][i]["time_stats"][j])*1e3)
    mean_s[j] = np.mean(mean_tmp)
    std_s[j] = np.std(mean_tmp)
    
plt.plot(test["id"],np.array(test["SemiImp_stats"])*1e3,marker='+',color='r',markersize = 10,linestyle='none')

plt.plot(test["id"],np.array(test["FluxBased_stats"])*1e3,marker='+',color='b',markersize = 10,linestyle='none')    

#mean_s = mean_s/ng
handles = [point,point2]
for k in range(0,ns):
    p = Line2D([0], [0], label=ude_solvers_str[k]+' (mean = {} $\pm$ {} ms)'.format(round(mean_s[k]),round(std_s[k])),
               marker='o', markersize=6, 
         markeredgecolor='w', markerfacecolor=colors[k], linestyle='')
    handles.append(p)


plt.legend(handles=handles,fontsize=10,loc=2,ncols=2)

plt.title('Benchmarking solver for run_random_climate for 300 years')
plt.grid()

# %% [markdown]
# ### Plotting the results in relation to glaciers features

# %%
fig= plt.figure(figsize=(10,8))
ax = fig.add_subplot(projection='polar')


ng=len(rgi_ids)
ns= len(ude_solvers_str)

mean_si = round(np.mean(test["SemiImp_stats"])*1e3)
std_si = round(np.std(test["SemiImp_stats"])*1e3)
mean_fb = round(np.mean(test["FluxBased_stats"])*1e3)
std_fb = round(np.std(test["FluxBased_stats"])*1e3)
mean_s =np.array([0]*ns)
std_s =np.array([0]*ns)
ds = utils.compile_run_output(gdirs)
length = [0]*ng
slope = [0]*ng
vol = [0]*ng
for g in range(0,ng):
    length[g] = (ds.isel(rgi_id=g).length.values[0])*1e-3
    vol[g] = (ds.isel(rgi_id=g).volume.values[0])*1e-9

    with xr.open_dataset(gdirs[g].get_filepath('model_geometry'),group="fl_0") as dg:
        dg = dg.load()
        
    tmp = dg.isel(time=0)
    ind = np.where(tmp.bed_h==tmp.surface_h)[0][0]
    slope[g] = (tmp.surface_h[0]-tmp.surface_h[ind]).values / (ds.isel(rgi_id=g).length.values[0])

outcome = np.array(test["FluxBased_stats"])*1e3
outcome2 = np.array(test["SemiImp_stats"])*1e3

# Plotting the data
ax.grid(True)
coeff=np.pi/270
c = ax.scatter(np.array(vol)*coeff, outcome, c=slope,s=100, cmap='viridis', alpha=0.75, 
               marker='+', label='Flux-Based')
c2 = ax.scatter(np.array(vol)*coeff, outcome2, c=slope,s=50, cmap='viridis', alpha=0.5, 
                marker='*', label ='Semi Implicit')
c3 = ax.scatter(np.array(vol)*coeff, outcome3, c=slope,s=50, cmap='viridis', alpha=0.75, marker='o',
               edgecolors='w', label='RDPK3Sp35')

ax.set_title('Influence of volume and slope on running time')



for j in [2]:
    mean_tmp=[]
    for i in range(0,ng):
        mean_tmp.append(np.mean(test["ude_settings"][i]["time_stats"][j])*1e3)
        
outcome3= mean_tmp

ax.legend()
labels =["0","30","60","90","120","150","180","210","240"]
ax.set_thetamin(-20)
ax.set_thetamax(200)
ax.set_thetagrids(range(0,180,20),labels)
ax.set_ylabel('Volume [$km^3$]', rotation=90,labelpad=10)
ax.yaxis.set_label_coords(-0.01,0.4)
ax.set_xlabel('Time [ms]')
ax.xaxis.set_label_coords(0.65,0.22)

fig.colorbar(c,ax=ax,shrink=0.5,label='Mean slope')
plt.show()
# Out:
# 2023-09-06 16:06:21: oggm.utils: Applying global task compile_run_output on 14 glaciers
# 2023-09-06 16:06:21: oggm.utils: Applying compile_run_output on 14 gdirs.

# %% [markdown]
# ## Benchmarking the iceflow models in relation to required simulation time

# %%
rgi_ids=["RGI60-11.03638","RGI60-11.03671","RGI60-11.03643","RGI60-11.03674","RGI60-11.03756", #Argentière, Gébroulaz, Mer de Glace,St-Sorlin, Sarennes
    "RGI60-16.00543","RGI60-16.01339", #Zongo, Antizana
    "RGI60-11.03232", #Ossoue
    "RGI60-11.03646", #Bossons
    "RGI60-15.03591", #Mera
    "RGI60-15.03733", #Khumbu
    "RGI60-14.07524", #Siachen
    "RGI60-13.54431", #Fedtchenko
    "RGI60-01.05355"] #Alexander

gdirs= workflow.init_glacier_directories(rgi_ids, from_prepro_level=4,
                                         prepro_base_url=base_url, prepro_border=160)


samples = 6
n_list = [25,50,100,150,200,300,400,500] #List of simulation durations
ng=len(rgi_ids)
evol_model = ["SemiImplicit", "FluxBased","SIA1D"]

cfg.PARAMS['Julia_solver']=jl.RDPK3Sp35() #Setting Julia solver to the one with best performance

#to benchmark all models with different simulation durations
def BenchmarkingTime(rgi_list, filename, gdirs): 

    reltol = 1e-5
    
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    

    for r in rgi_list:
        #Initialize glacier
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
    
        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:

                t_stats=[]
                for t in range(0,samples): 
                    tico = time.perf_counter()
                    workflow.execute_entity_task(tasks.run_random_climate, gdir, y0 = 2003, nyears=y,seed=1,store_fl_diagnostics=True,store_model_geometry=True)
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)
# Out:
# 2023-09-06 14:58:38: oggm.workflow: init_glacier_directories from prepro level 4 on 14 glaciers.
# 2023-09-06 14:58:38: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 14 glaciers
# 2023-09-06 14:58:38: oggm.workflow: WARNING: you are trying to run an entity task on 14 glaciers with multiprocessing turned off. OGGM will run faster with multiprocessing turned on.

# %%
BenchmarkingTime(rgi_ids,'data/random_climate_time.csv',gdirs)
# Out:
# 2023-09-06 14:58:53: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-06 14:58:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:58:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:16: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-06 14:59:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 14:59:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:36: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-06 15:00:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:00:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:13: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-06 15:01:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:33: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-06 15:01:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:01:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:04: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-06 15:02:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:02:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:03:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:09: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-06 15:04:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:04:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# ...
# 2023-09-06 15:33:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:33:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:10: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-06 15:34:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:34: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-06 15:34:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-06 15:34:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers

# %% [markdown]
# ### Plotting the results

# %%
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches


f, ax = plt.subplots(figsize=(12, 8))
handles, labels = plt.gca().get_legend_handles_labels()  

v=[]

ng=len(rgi_ids)
color_dict = {"SemiImplicit":'g', "FluxBased":'b',"SIA1D":'r'}

evol_model = ["SemiImplicit", "FluxBased","SIA1D"]

df = pd.read_csv('data/random_climate_time.csv') 
df = df.set_index(['rgi_id','n_years'])


for e in evol_model:
    for r in rgi_ids:
        df_tmp = df.loc[r]
        df_tmp[e].plot(ax=ax, marker = '+', markersize=4,alpha=0.25,color=color_dict[e],
                                 linewidth = 0.5)
        
    df.groupby(by=['n_years']).mean()[e].plot(ax=ax, marker = '+', markersize= 6,
    color=color_dict[e])


    
plt.ylabel('Running time [seconds]', fontsize = 14)
plt.xlabel('Simulation time [years]', fontsize = 14)
plt.title('Benchmarking iceflow models for different simulation time on task run_random_climate')

point = Line2D([0], [0], label='Mean SemiImplicit',marker='+', markersize=8, color='g',)

point2 = Line2D([0], [0], label=' Mean FluxBased', marker='+', markersize=8,color='b')
point3 = Line2D([0], [0], label=' Mean SIA1D', marker='+', markersize =6, color='r')

handles = [point,point2, point3]

plt.legend(handles=handles,fontsize=10)
plt.ylim([0,5])
plt.xlim([25,500])
plt.grid()
plt.show()

# %% [markdown]
# ### Attempt to benchmark iceflow models on various OGGM tasks

# %%
rgi_ids=["RGI60-11.03638","RGI60-11.03671","RGI60-11.03643","RGI60-11.03674","RGI60-11.03756", #Argentière, Gébroulaz, Mer de Glace,St-Sorlin, Sarennes
    "RGI60-16.00543","RGI60-16.01339", #Zongo, Antizana
    "RGI60-11.03232", #Ossoue
    "RGI60-15.03591", #Mera
    "RGI60-11.03646",
    "RGI60-14.07524", #Siachen
    "RGI60-01.05355"] #Alexander (Alaska)*

# %%
samples = 2
n_list = [50,100,150,200,300,400,500]
ng=len(rgi_ids)
evol_model = ["SemiImplicit", "FluxBased","SIA1D"]
cfg.PARAMS['Julia_solver']=jl.RDPK3Sp35() #Setting Julia solver to the one with best performance
gdirs = workflow.init_glacier_directories(rgi_ids, from_prepro_level=4, prepro_base_url=base_url, prepro_border=160)

def BenchmarkingRandom(rgi_list, filename,gdirs): #to benchmark all the glaciers from the list on different solvers

    reltol = 1e-5
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    
    for r in rgi_list:
        #Initialize glacier
        rgi = [r]
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
        
        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:

                t_stats=[]
                for t in range(0,samples):
                    tico = time.perf_counter()
                    workflow.execute_entity_task(tasks.run_random_climate, gdir, y0 = 2003, nyears=y,seed=1,
                                                init_model_filesuffix='_historical')
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
            
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)
    
def BenchmarkingConstant(rgi_list, filename, gdirs): #to benchmark all the glaciers from the list on different solvers

    reltol = 1e-5
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    
    for r in rgi_list:
        #Initialize glacier
        rgi = [r]
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
        
        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:

                t_stats = [] 
                for t in range(0,samples): 
                    tico = time.perf_counter()
                    workflow.execute_entity_task(tasks.run_constant_climate, gdir, y0 = 2003,
                                                 init_model_filesuffix='_historical', nyears=y)
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)
    
    
def BenchmarkingClimateData(rgi_list, filename,gdirs): #to benchmark all the glaciers from the list on different solvers

    reltol = 1e-5
    
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    n_list = [50,100,150,200,250,280]
    
    for r in rgi_list:
        #Initialize glacier
        rgi = [r]
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
        
        user ='gimenelu'
        m='MRI-ESM2-0'
        ssp='ssp126'

        fp = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_pr.nc'.format(user,m,ssp)
        ft = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_tas.nc'.format(user,m,ssp)

        #Bias correction of the files
        workflow.execute_entity_task(gcm_climate.process_cmip_data, gdir, 
                                                 filesuffix='_CMIP6_{}_{}'.format(m,ssp),  # recognize the climate file for later
                                                 fpath_temp=ft,  # temperature projections
                                                 fpath_precip=fp,  # precip projections
                                                 );
        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:
                ye = 2020 + y
                
                t_stats=[]
                for t in range(0,samples): 
                    tico = time.perf_counter()
                    sid = '_CMIP6_{}_{}'.format(m,ssp)
                    workflow.execute_entity_task(tasks.run_from_climate_data,gdir,ys=2020,ye=ye,
                                                             climate_filename='gcm_data',  # use gcm_data, not climate_historical
                                                             climate_input_filesuffix=sid,  # use the chosen scenario
                                                             init_model_filesuffix='_historical')
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
            
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)    
    
def BenchmarkingClimateData_hydro(rgi_list, filename,gdirs): #to benchmark all the glaciers from the list on different solvers
    
    cfg.PARAMS['store_model_geometry'] = True
    reltol = 1e-5
    
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    n_list = [50,100,150,200,250,280]
    
    for r in rgi_list:
        #Initialize glacier
        rgi = [r]
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
        
        user ='gimenelu'
        m='MRI-ESM2-0'
        ssp='ssp126'

        fp = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_pr.nc'.format(user,m,ssp)
        ft = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_tas.nc'.format(user,m,ssp)

        #Bias correction of the files
        workflow.execute_entity_task(gcm_climate.process_cmip_data, gdir, 
                                                 filesuffix='_CMIP6_{}_{}'.format(m,ssp),  # recognize the climate file for later
                                                 fpath_temp=ft,  # temperature projections
                                                 fpath_precip=fp,  # precip projections
                                                 );

        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:
                ye = 2020 + y
                t_stats = []
                for t in range(0,samples): 
                    tico = time.perf_counter()
                    sid = '_CMIP6_{}_{}'.format(m,ssp)
                    workflow.execute_entity_task(tasks.run_with_hydro,gdir,
                                        run_task=tasks.run_from_climate_data,
                                         ys=2020,ye=ye,
                                         climate_filename='gcm_data',  # use gcm_data, not climate_historical
                                         climate_input_filesuffix=sid,  # use the chosen scenario
                                        init_model_filesuffix='_historical')
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
            
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)  
    
    
def BenchmarkingSpinup(rgi_list, filename,gdirs): #to benchmark all the glaciers from the list on different solvers
    
    cfg.PARAMS['store_model_geometry'] = True
    reltol = 1e-5
    
    n = len(rgi_list)
    ude_benchmark = {"id":[], "SemiImplicit":[], "FluxBased":[],"SIA1D":[]}
    n_list = [50,100,150,200,250,280]
    
    for r in rgi_list:
        #Initialize glacier
        rgi = [r]
        ind = rgi_list.index(r)
        gdir=gdirs[ind]
        tasks.init_present_time_glacier(gdir)
        
        ude_benchmark["id"].append(r)
        
        user ='gimenelu'
        m='MRI-ESM2-0'
        ssp='ssp126'

        fp = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_pr.nc'.format(user,m,ssp)
        ft = '/mnt/{}/equipes/CRYODYN/OGGM/CMIP6-2300/{}_{}_r1i1p1f1_tas.nc'.format(user,m,ssp)

        #Bias correction of the files
        workflow.execute_entity_task(gcm_climate.process_cmip_data, gdir, 
                                                 filesuffix='_CMIP6_{}_{}'.format(m,ssp),  # recognize the climate file for later
                                                 fpath_temp=ft,  # temperature projections
                                                 fpath_precip=fp,  # precip projections
                                                 );

        
        for e in evol_model:
            cfg.PARAMS["evolution_model"] = e
            
            ude_settings={"time_stats":[]}
        
            for y in n_list:
                ye = 1950 + y
                t_stats = []
                for t in range(0,samples): 
                    tico = time.perf_counter()
                    sid = '_CMIP6_{}_{}'.format(m,ssp)
                    workflow.execute_entity_task(tasks.run_from_climate_data,gdir,
                                        fixed_geometry_spinup_yr=1950, ye=ye,
                                         climate_filename='gcm_data',  # use gcm_data, not climate_historical
                                         climate_input_filesuffix=sid)
                    
                    toco = time.perf_counter()
                    t_stats.append(toco-tico)

                t_stats_o = np.mean(t_stats)
            
                ude_settings["time_stats"].append(t_stats_o)  
                
            ude_benchmark[e].append(ude_settings)

    dfs= []
    for e in evol_model:
        
        df = pd.DataFrame({'rgi_id':[rgi_ids[i] for i in range(0,ng) for j in range(0,len(n_list))],
                           'n_years':n_list*ng,
                            'time_stats':[ude_benchmark[e][i]['time_stats'][j]for i in range(0,ng) for j in range(0,len(n_list))]})

        df = df.set_index(['rgi_id','n_years']) 
        dfs.append(df)
        
    result = pd.concat(dfs, axis=1)
    result.columns = evol_model   
    result.to_csv(filename)
# Out:
# 2023-09-08 14:21:46: oggm.workflow: init_glacier_directories from prepro level 4 on 12 glaciers.
# 2023-09-08 14:21:46: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 12 glaciers
# 2023-09-08 14:21:46: oggm.workflow: WARNING: you are trying to run an entity task on 12 glaciers with multiprocessing turned off. OGGM will run faster with multiprocessing turned on.

# %%
cfg.PARAMS['use_multiprocessing']=False

# %%
BenchmarkingRandom(rgi_ids,'data/random.csv',gdirs)
# Out:
# 2023-09-08 13:43:39: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:43:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:45: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:43:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:54: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:58: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:43:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:43:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:04: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:44:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:14: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:18: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:26: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:44:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:44:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:02: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:45:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:08: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:45:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:14: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:45:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:23: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:45:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:33: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:45:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:39: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:45:39: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:44: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:46: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:56: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:45:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:45:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:00: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:46:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:07: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:46:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:46:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:04: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:47:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:15: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:47:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:22: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:47:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:23: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:25: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:26: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:47:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:27: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:29: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:31: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:32: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:47:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:32: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:33: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:35: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:36: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:37: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:40: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:41: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:45: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:47: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:47:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:47: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:49: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:51: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:47:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:57: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:47:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:47:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:04: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:22: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:28: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:42: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:50: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:48:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:50: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:51: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:52: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:53: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:57: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:48:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:48:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:01: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:13: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:49:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:21: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:24: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:26: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:30: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:34: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:38: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:43: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:48: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:54: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:49:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:54: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:55: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:56: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:57: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:58: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:49:59: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:00: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:02: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:03: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:05: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:50:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:05: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:06: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:07: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:08: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:09: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:10: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:50:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:10: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:11: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:12: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:13: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:14: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:15: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:16: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:50:16: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:17: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:18: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:19: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers
# 2023-09-08 13:50:20: oggm.workflow: Execute entity tasks [run_random_climate] on 1 glaciers

# %%
BenchmarkingConstant(rgi_ids,'data/constant.csv',gdirs)
# Out:
# 2023-09-08 13:52:05: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:52:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:08: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:09: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:09: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:10: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:52:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:17: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:52:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:21: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:52:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:26: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:52:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:34: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:37: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:52:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:41: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:52:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:43: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:43: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:44: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:48: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:49: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:52:49: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:50: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:50: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:51: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:52:59: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:19: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:53:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:25: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:53:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:31: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:53:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:34: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:36: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:37: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:53:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:41: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:53:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:43: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:43: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:44: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:44: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:46: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:53:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:48: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:48: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:49: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:49: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:50: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:51: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:52: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:53:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:58: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:58: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:59: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:53:59: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:01: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:54:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:08: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:16: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:54:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:20: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:54:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:25: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:54:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:51: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:54:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:20: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:55:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:25: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:55:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:30: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:55:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:31: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:32: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:34: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:35: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:36: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:55:36: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:36: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:38: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:40: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:55:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:40: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:41: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:43: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:44: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:44: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:45: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:55:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:45: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:47: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:48: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:49: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:50: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:51: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:55:58: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:00: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:56:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:04: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:56:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:08: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:09: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:09: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:56:09: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:30: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:34: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:39: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:46: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:52: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:56:52: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:53: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:54: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:56: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:57: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:58: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:58: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:56:58: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:59: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:56:59: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:00: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:08: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:12: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:15: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:57:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:29: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:33: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:37: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:42: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:48: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:57:55: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:01: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:58:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:01: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:02: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:03: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:04: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:05: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:06: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:07: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:08: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:10: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:11: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:13: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:58:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:13: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:14: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:15: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:16: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:17: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:18: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:58:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:18: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:19: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:20: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:21: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:22: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:23: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:24: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:25: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:26: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:27: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers
# 2023-09-08 13:58:28: oggm.workflow: Execute entity tasks [run_constant_climate] on 1 glaciers

# %%
BenchmarkingClimateData(rgi_ids,'data/climatedata.csv',gdirs)
# Out:
# 2023-09-08 13:59:17: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 13:59:37: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 13:59:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:40: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:40: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:41: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 13:59:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:43: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:43: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:44: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:44: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:45: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 13:59:50: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:00:08: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:00:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:11: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:00:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:16: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:00:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:19: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:00:37: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:00:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:40: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:40: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:41: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:00:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:41: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:43: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:44: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:45: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:51: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:00:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:00:55: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:01:15: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:01:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:18: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:01:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:22: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:01:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:25: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:01:45: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:01:45: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:45: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:49: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:01:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:53: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:01:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:01:56: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:02:14: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:02:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:18: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:02:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:29: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:02:46: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:02:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:50: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:02:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:02:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:02: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:03:19: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:03:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:23: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:03:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:29: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:03:47: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:03:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:51: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:03:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:58: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:03:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:03:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:01: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:04:19: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:04:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:23: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:04:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:42: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:46: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:04:53: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:05:12: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:05:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:17: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:05:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:27: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:05:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:31: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:05:49: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:05:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:53: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:05:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:57: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:05:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:05:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:06:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers

# %%
BenchmarkingClimateData_hydro(rgi_ids,'data/climatedata_hydro.csv', gdirs)
# Out:
# 2023-09-08 14:21:54: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:22:12: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SemiImplicit`.
# 2023-09-08 14:22:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:17: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:22:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:19: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:19: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:20: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:20: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:21: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:21: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:23: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:22:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:26: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:26: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:28: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:22:45: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:22:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:50: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:51: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:22:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:52: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:52: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:53: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:53: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:54: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:57: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:22:57: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:57: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:22:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:02: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:23:22: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:23:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:26: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:27: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:23:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:29: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:38: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:40: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:23:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:42: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:42: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:44: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:23:45: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:24:03: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:24:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:05: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:05: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:06: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:06: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:07: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:07: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:08: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:24:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:14: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:24:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:18: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:24:36: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:24:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:38: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:38: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:38: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:39: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:39: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:40: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:41: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:24:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:42: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:42: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:44: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:44: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:46: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:24:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:24:50: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:25:08: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:25:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:13: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:25:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:19: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:20: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:22: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:25:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:26: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:25:45: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:25:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:49: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:25:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:50: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:50: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:51: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:52: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:53: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:54: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:54: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:57: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:25:59: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:25:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:02: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:02: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:02: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:04: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:26:22: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:26:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:25: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:26: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:26: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:27: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:26:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:29: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:29: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:32: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:26:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:35: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:35: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:35: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:37: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:26:55: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:26:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:56: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:57: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:57: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:58: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:26:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:00: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:27:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:00: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:01: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:02: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:02: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:05: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:06: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:07: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:08: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:27:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:12: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:27:30: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:27:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:35: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:27:35: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:39: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:52: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:55: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:27:59: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:03: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:28:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:03: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:04: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:05: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:05: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:06: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:06: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:07: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:07: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:08: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:09: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:28:27: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:28:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:27: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:28: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:29: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:29: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:30: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:31: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:32: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:33: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:28:33: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:34: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:35: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:36: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:37: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:38: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:39: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:41: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:42: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:43: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:44: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:28:44: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:45: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:46: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:47: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:48: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:49: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:50: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:28:51: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:29:09: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:29:09: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:10: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:11: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:12: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:13: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:14: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:29:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:14: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:15: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:16: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:17: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:18: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:19: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:19: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:20: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:29:20: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:20: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:21: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:21: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:21: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:22: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:23: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers
# 2023-09-08 14:29:24: oggm.workflow: Execute entity tasks [run_with_hydro] on 1 glaciers

# %%
BenchmarkingSpinup(rgi_ids,'data/fixedspinup.csv', gdirs)
# Out:
# 2023-09-08 14:30:39: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:30:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:01: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:31:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:05: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:31:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:06: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03638: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:31:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:07: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03638: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:31:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:10: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:35: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:31:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:35: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03671: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:31:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03671: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:38: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:31:56: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:31:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:31:59: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:31:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:08: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:32:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:08: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03643: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:32:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:08: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03643: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:32:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:11: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:33: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:32:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:37: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:32:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:37: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03674: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:32:37: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:38: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03674: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:32:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:38: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:39: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:40: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:40: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:32:58: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:32:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:32:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:01: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:33:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:04: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:33:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03756: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03756: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:06: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:07: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:33:25: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:33:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:28: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:33:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:32: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:33: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:34: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:33:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:34: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-16.00543: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:33:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:34: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-16.00543: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:33:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:34: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:35: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:36: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:37: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:33:55: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:33:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:58: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:33:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:58: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:33:59: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:00: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:01: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:02: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:03: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:04: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:05: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:07: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:34:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:07: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-16.01339: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:34:07: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:08: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-16.01339: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:34:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:08: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:09: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:10: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:10: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:29: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:30: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:31: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:34:31: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# ...
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:35:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:49: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-11.03646: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:35:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:35:52: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:36:11: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:36:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:11: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:12: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:13: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:14: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:15: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:16: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:36:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:16: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:17: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:18: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:19: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:20: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:21: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:23: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:24: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:36:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:24: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-14.07524: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:36:24: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:25: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-14.07524: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:36:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:25: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:26: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:27: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:28: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:29: oggm.workflow: Execute entity tasks [process_cmip_data] on 1 glaciers
# 2023-09-08 14:36:47: oggm.cfg: PARAMS['evolution_model'] changed from `SIA1D` to `SemiImplicit`.
# 2023-09-08 14:36:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:47: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:48: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:49: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.cfg: PARAMS['evolution_model'] changed from `SemiImplicit` to `FluxBased`.
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:50: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:51: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:52: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:53: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:54: oggm.cfg: PARAMS['evolution_model'] changed from `FluxBased` to `SIA1D`.
# 2023-09-08 14:36:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:54: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-01.05355: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:36:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:54: oggm.core.flowline: JuliaError occurred during task flowline_model_run on RGI60-01.05355: BoundsError: attempt to access 51-element Vector{Union{Float64, Py}} at index [52]
# Stacktrace:
#  [1] setindex!
#    @ ./array.jl:966 [inlined]
#  [2] update_diag!(diag_jl::diag{Float64}, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64, j::Int64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:165
#  [3] initialize_diag!(diag_jl::diag{Float64}, nₜm::Int64, fac::Int64, diff::Int64, SIA1D::Py, l_var::PyList{Any}, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D.jl:156
#  [4] glacier_evolution_store(; SIA1D::Py, solver::RDPK3Sp35{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, reltol::Float64, y0::Int64, y1::Int64, l_var::PyList{Any}, do_geom::Int64, do_fl_diag::Int64, mb_step::String, dyn_spin_thick::Float64)
#    @ Main ~/oggm/oggm/core/SIA1D_utils.jl:103
#  [5] pyjlany_call(self::typeof(glacier_evolution_store), args_::Py, kwargs_::Py)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/any.jl:34
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall ~/.julia/packages/PythonCall/1f5yE/src/jlwrap/base.jl:69
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.C ~/.julia/packages/PythonCall/1f5yE/src/cpython/jlwrap.jl:47
# 2023-09-08 14:36:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:54: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:55: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:56: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers
# 2023-09-08 14:36:57: oggm.workflow: Execute entity tasks [run_from_climate_data] on 1 glaciers

# %% [markdown]
# ### Plotting the results

# %%
df2
# Out:
#          SemiImplicit  FluxBased     SIA1D
# n_years
# 50           0.078600   0.064840  0.286880
# 100          0.173357   0.293034  0.152593
# 150          0.253875   0.451204  0.217321
# 200          0.303221   0.649416  0.299449
# 250          0.383563   0.843848  0.346363
# 280          0.424514   0.952057  0.417753

# %%
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
import geopandas as gpd
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(12, 8))
handles, labels = plt.gca().get_legend_handles_labels()  

ng=len(rgi_ids)
marker_dict =  {"SemiImplicit":'+', "FluxBased":'v',"SIA1D":'o'}

point = Line2D([0], [0], label='Semi Implicit', marker='+', markersize=10, 
         markeredgecolor='k', markerfacecolor='k', linestyle='')

point2 = Line2D([0], [0], label='Flux Based', marker='v', markersize=10, 
         markeredgecolor='k', markerfacecolor='k', linestyle='')

point3 = Line2D([0], [0], label='SIA1D', marker='o', markersize=10, 
         markeredgecolor='k', markerfacecolor='k', linestyle='')

handles=[point, point2, point3]

evol_model = ["SemiImplicit", "FluxBased","SIA1D"]
nm = len(evol_model)

tasks = ['random', 'constant', 'climatedata','climatedata_hydro','fixedspinup']

tasks_dict = {'random':'tab:blue', 'constant':'tab:orange', 'climatedata':'tab:green',
              'climatedata_hydro':'tab:red','fixedspinup':'tab:purple'}

tasks_label = ['random_climate', 'constant_climate', 'GCM_data_climate','GCM_data_climate_with_hydro',
            'GCM_data_climate_fixed_spinup']


dfs = []
custom_lines = []
for task in tasks:

    df = pd.read_csv('data/{}.csv'.format(task)) 
    df = df.set_index(['rgi_id','n_years'])
    df2 = df.groupby(by=['n_years']).mean()
    dfs.append(df2)
    
    for i in range(0,nm):
        dfm = df2.iloc[:,i]
        for y in range(0,len(dfm)):
            ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
                       c = tasks_dict[task],s=50,edgecolors='w')
    
    l = Line2D([0], [0], color=tasks_dict[task], lw=4, label = tasks_label[tasks.index(task)])
    custom_lines.append(l)
    
    
    
ax.legend(handles=handles+custom_lines)  
ax.set_xlabel('Simulation time [years]')
ax.set_ylabel('Running time [ms]')
ax.grid()
# Out:
# /tmp/ipykernel_9684/3014347048.py:47: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
# /tmp/ipykernel_9684/3014347048.py:47: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
# /tmp/ipykernel_9684/3014347048.py:47: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
# /tmp/ipykernel_9684/3014347048.py:47: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
# /tmp/ipykernel_9684/3014347048.py:47: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(dfm.index.values[y],dfm.values[y]*1e3,marker=marker_dict[evol_model[i]],
